# %%
import sys
import os
from pathlib import Path
sys.path.append(str(Path.cwd().parent))

# %%
from imgw_api import *
from hydro_stats import *

# %% [markdown]
# <h1>IMGW API</h1>
#
# Moduł imgw_api.py pozwala na połączenie się z API IMGW w celu pobrania aktualnych danych
# Do pobrania danych potrzena jest wyłącznie znajomość identyfikatora (kodu) stacji lub jej nazwa.

# %% [markdown]
# <h2>Dane hydrologiczne</h2>

# %%
# Inicjalizacja instancji klasy HYDRO
api_hydro = HYDRO(station_id=150160180)

# Pobieranie danych dla wybranej stacji hydrologicznej
api_hydro.get_hydro_data()
# Out:
# Status code: 200
# [{'kod_stacji': '150160180',
#   'nazwa_stacji': 'KŁODZKO',
#   'lon': '16.658611',
#   'lat': '50.4425',
#   'stan': '206',
#   'stan_data': '2024-09-19 12:50:00',
#   'przelyw': '89',
#   'przeplyw_data': '2024-09-19 12:50:00'}]

# %%
# Zapisywanie ostatniej odpowiedzi z API do pliku json
api_hydro.save_json_to_file(api_hydro.data)
# Out:
# 1

# %% [markdown]
# <h2>Dane synoptyczne</h2>

# %%
# Inicjalizacja instancji klasy SYNOP
api_synop_id = SYNOP(station_id=12500)
api_synop_name = SYNOP(station_name='jeleniagora')

# Pobieranie danych dla wybranej stacji hydrologicznej
api_synop_id.get_synop_data()
# Out:
# Status code: 200
# {'id_stacji': '12500',
#  'stacja': 'Jelenia Góra',
#  'data_pomiaru': '2024-09-19',
#  'godzina_pomiaru': '12',
#  'temperatura': '18.2',
#  'predkosc_wiatru': '5',
#  'kierunek_wiatru': '70',
#  'wilgotnosc_wzgledna': '63.6',
#  'suma_opadu': '1.2',
#  'cisnienie': '1025.4'}

# %%
api_synop_name.get_synop_data()
# Out:
# Status code: 200
# {'id_stacji': '12500',
#  'stacja': 'Jelenia Góra',
#  'data_pomiaru': '2024-09-19',
#  'godzina_pomiaru': '12',
#  'temperatura': '18.2',
#  'predkosc_wiatru': '5',
#  'kierunek_wiatru': '70',
#  'wilgotnosc_wzgledna': '63.6',
#  'suma_opadu': '1.2',
#  'cisnienie': '1025.4'}

# %% [markdown]
# <h2>Dane meteorologiczne</h2>

# %%
# Inicjalizacja instancji klasy METEO
api_meteo = METEO(station_id=253180090)

# Pobieranie danych dla wybranej stacji hydrologicznej
api_meteo.get_meteo_data()
# Out:
# Status code: 200
# [{'kod_stacji': '253180090',
#   'nazwa_stacji': 'ŚLIWICE',
#   'lon': '18.175833',
#   'lat': '53.704722',
#   'temperatura_gruntu': '24.94',
#   'temperatura_gruntu_data': '2024-09-19 12:50:00',
#   'wiatr_kierunek': '206',
#   'wiatr_kierunek_data': '2024-09-19 12:50:00',
#   'wiatr_srednia_predkosc': '3.2',
#   'wiatr_srednia_predkosc_data': '2024-09-19 12:50:00',
#   'wiatr_predkosc_maksymalna': '5.9',
#   'wiatr_predkosc_maksymalna_data': '2024-09-19 12:50:00',
#   'wilgotnosc_wzgledna': '46.72',
#   'wilgotnosc_wzgledna_data': '2024-09-19 12:50:00',
#   'wiatr_poryw_10min': None,
#   'wiatr_poryw_10min_data': None,
#   'opad_10min': '0',
#   'opad_10min_data': '2024-09-19 12:20:00'}]

# %% [markdown]
# <h2>Ostrzeżenia hydrologiczne i meteorologiczne</h2>

# %%
# Inicjalizacja instancji klasy SYNOP
api_warning_hydro = WARNINGS(warning_type="hydro")

# Pobieranie ostrzeżeń hydrologicznych
api_warning_hydro.get_warnings()
# Out:
# Status code: 200
# [{'opublikowano': '2024-07-01 11:03:18',
#   'stopień': '-1',
#   'data_od': '2024-07-01 11:03:58',
#   'data_do': '9999-12-31 23:59:59',
#   'prawdopodobienstwo': '90',
#   'numer': '100',
#   'biuro': 'Biuro Prognoz Hydrologicznych we Wrocławiu, Wydział Prognoz i Opracowań Hydrologicznych w Poznaniu',
#   'zdarzenie': 'susza hydrologiczna',
#   'przebieg': 'W związku z występującymi niskimi przepływami wody, w kolejnych dniach na odcinku górnej Warty od Liswarty do Zbiornika Jeziorsko, spodziewane jest dalsze utrzymywanie się przepływów wody poniżej SNQ.',
#   'komentarz': 'Ostrzeżenie wydawane jest w sytuacji, gdy aktualne lub prognozowane wartości przepływu na stacjach wodowskazowych uznanych za reprezentatywne układają się poniżej SNQ przez minimum 10 dni w obrębie jednego obszaru hydrologicznego (który obejmuje grupę zlewni monitorowanych przez PSHM).',
#   'wojewodztwo': 'łódzkie',
#   'obszar': 'Warta górna od Liswarty do Widawki, Warta górna od Widawki do Zb. Jeziorsko'},
#  {'opublikowano': '2024-06-20 10:24:19',
#   'stopień': '-1',
#   'data_od': '2024-06-20 10:30:00',
#   'data_do': '9999-12-31 23:59:59',
#   'prawdopodobienstwo': '95',
#   'numer': '168',
#   'biuro': 'Biuro Prognoz Hydrologicznych w Krakowie, Wydział Prognoz i Opracowań Hydrologicznych w Warszawie',
#   'zdarzenie': 'susza hydrologiczna',
#   'przebieg': 'W związku z występującymi niskimi przepływami wody, w kolejnych dniach, na obszarze zlewni środkowej Narwi spodziewane jest dalsze utrzymywanie się przepływów wody poniżej SNQ.',
#   'komentarz': 'Ostrzeżenie wydawane jest w sytuacji, gdy aktualne lub prognozowane wartości przepływu na stacjach wodowskazowych uznanych za reprezentatywne układają się poniżej SNQ przez minimum 10 dni w obrębie jednego obszaru hydrologicznego (który obejmuje grupę zlewni monitorowanych przez PSHM).',
#   'wojewodztwo': 'podlaskie',
#   'obszar': 'Środkowa Narew'},
#  {'opublikowano': '2024-06-20 10:43:00',
#   'stopień': '-1',
#   'data_od': '2024-06-20 11:00:00',
#   'data_do': '9999-12-31 23:59:59',
#   'prawdopodobienstwo': '95',
#   'numer': '169',
#   'biuro': 'Biuro Prognoz Hydrologicznych w Krakowie, Wydział Prognoz i Opracowań Hydrologicznych w Warszawie',
#   'zdarzenie': 'susza hydrologiczna',
#   'przebieg': 'W związku z występującymi niskimi przepływami wody, w kolejnych dniach, na obszarze zlewni dolnej Narwi spodziewane jest dalsze utrzymywanie się przepływów wody poniżej SNQ.',
#   'komentarz': 'Ostrzeżenie wydawane jest w sytuacji, gdy aktualne lub prognozowane wartości przepływu na stacjach wodowskazowych uznanych za reprezentatywne układają się poniżej SNQ przez minimum 10 dni w obrębie jednego obszaru hydrologicznego (który obejmuje grupę zlewni monitorowanych przez PSHM).`',
#   'wojewodztwo': 'mazowieckie',
#   'obszar': 'Dolna Narew'},
#  {'opublikowano': '2024-06-20 10:47:30',
#   'stopień': '-1',
#   'data_od': '2024-06-20 11:00:00',
#   'data_do': '9999-12-31 23:59:59',
#   'prawdopodobienstwo': '95',
#   'numer': '171',
#   'biuro': 'Biuro Prognoz Hydrologicznych w Krakowie, Wydział Prognoz i Opracowań Hydrologicznych w Warszawie',
#   'zdarzenie': 'susza hydrologiczna',
#   'przebieg': 'W związku z występującymi niskimi przepływami wody, w kolejnych dniach, na obszarze zlewni Pisy spodziewane jest dalsze utrzymywanie się przepływów wody poniżej SNQ.',
#   'komentarz': 'Ostrzeżenie wydawane jest w sytuacji, gdy aktualne lub prognozowane wartości przepływu na stacjach wodowskazowych uznanych za reprezentatywne układają się poniżej SNQ przez minimum 10 dni w obrębie jednego obszaru hydrologicznego (który obejmuje grupę zlewni monitorowanych przez PSHM).',
#   'wojewodztwo': 'podlaskie',
#   'obszar': 'Pisa'},
#  {'opublikowano': '2024-06-20 10:45:51',
#   'stopień': '-1',
#   'data_od': '2024-06-20 11:00:00',
#   'data_do': '9999-12-31 23:59:59',
#   'prawdopodobienstwo': '95',
#   'numer': '170',
#   'biuro': 'Biuro Prognoz Hydrologicznych w Krakowie, Wydział Prognoz i Opracowań Hydrologicznych w Warszawie',
#   'zdarzenie': 'susza hydrologiczna',
#   'przebieg': 'W związku z występującymi niskimi przepływami wody, w kolejnych dniach, na obszarze zlewni górnego Ełku i górnej Legi spodziewane jest dalsze utrzymywanie się przepływów wody poniżej SNQ.',
#   'komentarz': 'Ostrzeżenie wydawane jest w sytuacji, gdy aktualne lub prognozowane wartości przepływu na stacjach wodowskazowych uznanych za reprezentatywne układają się poniżej SNQ przez minimum 10 dni w obrębie jednego obszaru hydrologicznego (który obejmuje grupę zlewni monitorowanych przez PSHM).',
#   'wojewodztwo': 'warmińsko-mazurskie',
#   'obszar': 'Górny Ełk,Górna Lega'},
#  {'opublikowano': '2024-06-20 11:01:14',
#   'stopień': '-1',
#   'data_od': '2024-06-20 11:05:00',
#   'data_do': '9999-12-31 23:59:59',
#   'prawdopodobienstwo': '90',
#   'numer': '90',
#   'biuro': 'Biuro Prognoz Hydrologicznych we Wrocławiu, Wydział Prognoz i Opracowań Hydrologicznych w Poznaniu',
#   'zdarzenie': 'susza hydrologiczna',
#   'przebieg': 'W związku z występującymi niskimi przepływami wody, w kolejnych dniach na odcinku środkowej Warty od Zbiornika Jeziorsko do Wełny, spodziewane jest dalsze utrzymywanie się przepływów wody poniżej SNQ.',
#   'komentarz': 'Ostrzeżenie wydawane jest w sytuacji, gdy aktualne lub prognozowane wartości przepływu na stacjach wodowskazowych uznanych za reprezentatywne układają się poniżej SNQ przez minimum 10 dni w obrębie jednego obszaru hydrologicznego (który obejmuje grupę zlewni monitorowanych przez PSHM).',
#   'wojewodztwo': 'łódzkie',
#   'obszar': 'Warta środkowa od Zb. Jeziorsko do Prosny, Warta środkowa od Prosny do Wełny'},
#  {'opublikowano': '2024-09-19 12:15:17',
#   'stopień': '3',
#   'data_od': '2024-09-19 12:15:52',
#   'data_do': '2024-09-25 12:00:00',
#   'prawdopodobienstwo': '95',
#   'numer': '171',
#   'biuro': 'Biuro Prognoz Hydrologicznych we Wrocławiu, Wydział Prognoz i Opracowań Hydrologicznych w Poznaniu',
#   'zdarzenie': 'wezbranie stany alarmowe ',
#   'przebieg': 'Stany wody na Odrze granicznej w województwie lubuskim oraz ujściowym odcinku Warty  będą miały tendencję wzrostową w strefie wody wysokiej, początkowo z przekroczeniem stanu ostrzegawczego a następnie alarmowego.',
#   'komentarz': 'Zmiana dotyczy obszaru: dodano ujściowy odcinek Warty',
#   'wojewodztwo': 'lubuskie',
#   'obszar': 'Odra graniczna w województwie lubuskim, ujściowy odcinek Warty'},
#  {'opublikowano': '2024-07-25 11:14:48',
#   'stopień': '-1',
#   'data_od': '2024-07-25 11:15:27',
#   'data_do': '9999-12-31 23:59:59',
#   'prawdopodobienstwo': '90',
#   'numer': '125',
#   'biuro': 'Biuro Prognoz Hydrologicznych we Wrocławiu, Wydział Prognoz i Opracowań Hydrologicznych w Poznaniu',
#   'zdarzenie': 'susza hydrologiczna',
#   'przebieg': 'W związku z występującymi niskimi przepływami wody, w kolejnych dniach w zlewni Wełny spodziewane jest dalsze utrzymywanie się przepływów wody poniżej SNQ.',
#   'komentarz': 'Ostrzeżenie wydawane jest w sytuacji, gdy aktualne lub prognozowane wartości przepływu na stacjach wodowskazowych uznanych za reprezentatywne układają się poniżej SNQ przez minimum 10 dni w obrębie jednego obszaru hydrologicznego (który obejmuje grupę zlewni monitorowanych przez PSHM).',
#   'wojewodztwo': 'kujawsko-pomorskie',
#   'obszar': 'Wełna'},
#  {'opublikowano': '2024-08-09 09:23:35',
#   'stopień': '-1',
#   'data_od': '2024-08-09 09:24:12',
#   'data_do': '9999-12-31 23:59:59',
#   'prawdopodobienstwo': '95',
#   'numer': '221',
#   'biuro': 'Biuro Prognoz Hydrologicznych w Krakowie, Wydział Prognoz i Opracowań Hydrologicznych w Warszawie',
#   'zdarzenie': 'susza hydrologiczna',
#   'przebieg': 'W związku z występującymi niskimi przepływami wody, w kolejnych dniach na obszarze zlewni Łyny, spodziewane jest dalsze utrzymywanie się przepływów wody poniżej SNQ.',
#   'komentarz': 'Ostrzeżenie wydawane jest w sytuacji, gdy aktualne lub prognozowane wartości przepływu na stacjach wodowskazowych uznanych za reprezentatywne układają się poniżej SNQ przez minimum 10 dni w obrębie jednego obszaru hydrologicznego (który obejmuje grupę zlewni monitorowanych przez PSHM).',
#   'wojewodztwo': 'warmińsko-mazurskie',
#   'obszar': 'Zlewnia Łyny'},
#  {'opublikowano': '2024-07-09 07:56:58',
#   'stopień': '-1',
#   'data_od': '2024-07-09 08:00:00',
#   'data_do': '9999-12-31 23:59:59',
#   'prawdopodobienstwo': '95',
#   'numer': '282',
#   'biuro': 'Biuro Prognoz Hydrologicznych w Krakowie, Wydział Prognoz i Opracowań Hydrologicznych w Krakowie',
#   'zdarzenie': 'susza hydrologiczna',
#   'przebieg': 'W związku z występującymi niskimi przepływami wody na obszarze zlewni Bugu do ujścia Uherki spodziewane jest dalsze utrzymywanie się przepływów wody poniżej SNQ.',
#   'komentarz': 'Ostrzeżenie wydawane jest w sytuacji, gdy aktualne lub prognozowane wartości przepływu na stacjach wodowskazowych uznanych za reprezentatywne układają się poniżej SNQ przez minimum 10 dni w obrębie jednego obszaru hydrologicznego (który obejmuje grupę zlewni monitorowanych przez PSHM).',
#   'wojewodztwo': 'lubelskie',
#   'obszar': 'zlewnia Bugu do ujścia Uherki'},
#  {'opublikowano': '2024-07-03 10:10:40',
#   'stopień': '-1',
#   'data_od': '2024-07-03 10:15:44',
#   'data_do': '9999-12-31 23:59:59',
#   'prawdopodobienstwo': '95',
#   'numer': '110',
#   'biuro': 'Biuro Prognoz Hydrologicznych w Gdyni, Wydział Prognoz i Opracowań Hydrologicznych w Gdyni',
#   'zdarzenie': 'susza hydrologiczna',
#   'przebieg': 'W związku z występującymi niskimi przepływami wody, w kolejnych dniach, na obszarze zlewni Tążyny, spodziewane jest dalsze utrzymywanie się przepływów wody poniżej SNQ.',
#   'komentarz': 'Ostrzeżenie wydawane jest w sytuacji, gdy aktualne lub prognozowane wartości przepływu na stacjach wodowskazowych uznanych za reprezentatywne układają się poniżej SNQ przez minimum 10 dni w obrębie jednego obszaru hydrologicznego (który obejmuje grupę zlewni monitorowanych przez PSHM).',
#   'wojewodztwo': 'kujawsko-pomorskie',
#   'obszar': 'Tążyna'},
#  {'opublikowano': '2024-06-24 10:16:23',
#   'stopień': '-1',
#   'data_od': '2024-06-24 10:30:00',
#   'data_do': '9999-12-31 23:59:59',
#   'prawdopodobienstwo': '95',
#   'numer': '175',
#   'biuro': 'Biuro Prognoz Hydrologicznych w Krakowie, Wydział Prognoz i Opracowań Hydrologicznych w Warszawie',
#   'zdarzenie': 'susza hydrologiczna',
#   'przebieg': 'W związku z występującymi niskimi przepływami wody, w kolejnych dniach, na obszarze zlewni Biebrzy spodziewane jest dalsze utrzymywanie się przepływów wody poniżej SNQ.',
#   'komentarz': 'Ostrzeżenie wydawane jest w sytuacji, gdy aktualne lub prognozowane wartości przepływu na stacjach wodowskazowych uznanych za reprezentatywne układają się poniżej SNQ przez minimum 10 dni w obrębie jednego obszaru hydrologicznego (który obejmuje grupę zlewni monitorowanych przez PSHM).',
#   'wojewodztwo': 'podlaskie',
#   'obszar': 'Biebrza'},
#  {'opublikowano': '2024-08-09 10:26:16',
#   'stopień': '-1',
#   'data_od': '2024-08-09 10:26:47',
#   'data_do': '9999-12-31 23:59:59',
#   'prawdopodobienstwo': '90',
#   'numer': '132',
#   'biuro': 'Biuro Prognoz Hydrologicznych w Gdyni, Wydział Prognoz i Opracowań Hydrologicznych w Gdyni',
#   'zdarzenie': 'susza hydrologiczna',
#   'przebieg': 'W związku z występującymi niskimi przepływami wody, w kolejnych dniach, na Dolnej Wiśle (woj. pomorskie), spodziewane jest dalsze utrzymywanie się przepływów wody poniżej SNQ.',
#   'komentarz': 'Ostrzeżenie wydawane jest w sytuacji, gdy aktualne lub prognozowane wartości przepływu na stacjach wodowskazowych uznanych za reprezentatywne układają się poniżej SNQ przez minimum 10 dni w obrębie jednego obszaru hydrologicznego (który obejmuje grupę zlewni monitorowanych przez PSHM).',
#   'wojewodztwo': 'pomorskie',
#   'obszar': 'Wisła od Torunia do Tczewa (rz)'},
#  {'opublikowano': '2024-08-06 10:16:04',
#   'stopień': '-1',
#   'data_od': '2024-08-06 10:16:41',
#   'data_do': '9999-12-31 23:59:59',
#   'prawdopodobienstwo': '95',
#   'numer': '217',
#   'biuro': 'Biuro Prognoz Hydrologicznych w Krakowie, Wydział Prognoz i Opracowań Hydrologicznych w Warszawie',
#   'zdarzenie': 'susza hydrologiczna',
#   'przebieg': 'W związku z występującymi niskimi przepływami wody, w kolejnych dniach na obszarze zlewni Górnej Narwi, spodziewane jest dalsze utrzymywanie się przepływów wody poniżej SNQ.',
#   'komentarz': 'Ostrzeżenie wydawane jest w sytuacji, gdy aktualne lub prognozowane wartości przepływu na stacjach wodowskazowych uznanych za reprezentatywne układają się poniżej SNQ przez minimum 10 dni w obrębie jednego obszaru hydrologicznego (który obejmuje grupę zlewni monitorowanych przez PSHM).',
#   'wojewodztwo': 'podlaskie',
#   'obszar': 'Górna Narew, Leśna'},
#  {'opublikowano': '2024-08-09 10:27:09',
#   'stopień': '-1',
#   'data_od': '2024-08-09 10:27:55',
#   'data_do': '9999-12-31 23:59:59',
#   'prawdopodobienstwo': '90',
#   'numer': '133',
#   'biuro': 'Biuro Prognoz Hydrologicznych w Gdyni, Wydział Prognoz i Opracowań Hydrologicznych w Gdyni',
#   'zdarzenie': 'susza hydrologiczna',
#   'przebieg': 'W związku z występującymi niskimi przepływami wody, w kolejnych dniach, na rzece Mień, spodziewane jest dalsze utrzymywanie się przepływów wody poniżej SNQ.',
#   'komentarz': 'Ostrzeżenie wydawane jest w sytuacji, gdy aktualne lub prognozowane wartości przepływu na stacjach wodowskazowych uznanych za reprezentatywne układają się poniżej SNQ przez minimum 10 dni w obrębie jednego obszaru hydrologicznego (który obejmuje grupę zlewni monitorowanych przez PSHM).',
#   'wojewodztwo': 'kujawsko-pomorskie',
#   'obszar': 'Mień'},
#  {'opublikowano': '2024-06-19 10:23:44',
#   'stopień': '-1',
#   'data_od': '2024-06-19 10:24:29',
#   'data_do': '9999-12-31 23:59:59',
#   'prawdopodobienstwo': '95',
#   'numer': '96',
#   'biuro': 'Biuro Prognoz Hydrologicznych w Gdyni, Wydział Prognoz i Opracowań Hydrologicznych w Gdyni',
#   'zdarzenie': 'susza hydrologiczna',
#   'przebieg': 'W związku z występującymi niskimi przepływami wody, w kolejnych dniach, na obszarze zlewni rzeki Drwęca od źródła do Welu, spodziewane jest dalsze utrzymywanie się przepływów wody poniżej SNQ.',
#   'komentarz': 'Ostrzeżenie wydawane jest w sytuacji, gdy aktualne lub prognozowane wartości przepływu na stacjach wodowskazowych uznanych za reprezentatywne układają się poniżej SNQ przez minimum 10 dni w obrębie jednego obszaru hydrologicznego (który obejmuje grupę zlewni monitorowanych przez PSHM).',
#   'wojewodztwo': 'warmińsko-mazurskie',
#   'obszar': 'Drwęca od źródła do Welu'},
#  {'opublikowano': '2024-08-06 11:06:02',
#   'stopień': '-1',
#   'data_od': '2024-08-06 11:30:00',
#   'data_do': '9999-12-31 23:59:59',
#   'prawdopodobienstwo': '90',
#   'numer': '138',
#   'biuro': 'Biuro Prognoz Hydrologicznych we Wrocławiu, Wydział Prognoz i Opracowań Hydrologicznych w Poznaniu',
#   'zdarzenie': 'susza hydrologiczna',
#   'przebieg': 'W związku z występującymi niskimi przepływami wody, w kolejnych dniach na odcinku środkowej Warty od Wełny do Noteci, spodziewane jest dalsze utrzymywanie się przepływów wody poniżej SNQ.',
#   'komentarz': 'Ostrzeżenie wydawane jest w sytuacji, gdy aktualne lub prognozowane wartości przepływu na stacjach wodowskazowych uznanych za reprezentatywne układają się poniżej SNQ przez minimum 10 dni w obrębie jednego obszaru hydrologicznego (który obejmuje grupę zlewni monitorowanych przez PSHM).',
#   'wojewodztwo': 'lubuskie',
#   'obszar': 'Warta środkowa od Wełny do Noteci'},
#  {'opublikowano': '2024-07-13 07:42:17',
#   'stopień': '-1',
#   'data_od': '2024-07-13 08:00:00',
#   'data_do': '9999-12-31 23:59:59',
#   'prawdopodobienstwo': '95',
#   'numer': '296',
#   'biuro': 'Biuro Prognoz Hydrologicznych w Krakowie, Wydział Prognoz i Opracowań Hydrologicznych w Krakowie',
#   'zdarzenie': 'susza hydrologiczna',
#   'przebieg': 'W związku z występującymi niskimi przepływami wody na obszarze zlewni Sanu od ujścia Wiaru spodziewane jest dalsze utrzymywanie się przepływów wody poniżej SNQ.',
#   'komentarz': 'Ostrzeżenie wydawane jest w sytuacji, gdy aktualne lub prognozowane wartości przepływu na stacjach wodowskazowych uznanych za reprezentatywne układają się poniżej SNQ przez minimum 10 dni w obrębie jednego obszaru hydrologicznego (który obejmuje grupę zlewni monitorowanych przez PSHM).',
#   'wojewodztwo': 'lubelskie',
#   'obszar': 'zlewnia Sanu od ujścia Wiaru do ujścia do Wisły'},
#  {'opublikowano': '2024-08-30 08:47:11',
#   'stopień': '-1',
#   'data_od': '2024-08-30 09:00:00',
#   'data_do': '9999-12-31 23:59:59',
#   'prawdopodobienstwo': '90',
#   'numer': '234',
#   'biuro': 'Biuro Prognoz Hydrologicznych w Krakowie, Wydział Prognoz i Opracowań Hydrologicznych w Warszawie',
#   'zdarzenie': 'susza hydrologiczna',
#   'przebieg': 'W związku z występującymi niskimi przepływami wody, w kolejnych dniach w rzekach zlewni Niemna spodziewane jest dalsze utrzymywanie się przepływów wody poniżej SNQ.',
#   'komentarz': 'Ostrzeżenie wydawane jest w sytuacji, gdy aktualne lub prognozowane wartości przepływu na stacjach wodowskazowych uznanych za reprezentatywne układają się poniżej SNQ przez minimum 10 dni w obrębie jednego obszaru hydrologicznego (który obejmuje grupę zlewni monitorowanych przez PSHM).',
#   'wojewodztwo': 'podlaskie',
#   'obszar': 'zlewnia rzeki Niemen'},
#  {'opublikowano': '2024-07-28 08:18:28',
#   'stopień': '-1',
#   'data_od': '2024-07-28 08:19:25',
#   'data_do': '9999-12-31 23:59:59',
#   'prawdopodobienstwo': '95',
#   'numer': '338',
#   'biuro': 'Biuro Prognoz Hydrologicznych w Krakowie, Wydział Prognoz i Opracowań Hydrologicznych w Krakowie',
#   'zdarzenie': 'susza hydrologiczna',
#   'przebieg': 'W związku z występującymi niskimi przepływami wody na obszarze zlewni Bugu poniżej ujścia Uherki do Krzyczewa spodziewane jest dalsze utrzymywanie się przepływów wody poniżej SNQ.',
#   'komentarz': 'Ostrzeżenie wydawane jest w sytuacji, gdy aktualne lub prognozowane wartości przepływu na stacjach wodowskazowych uznanych za reprezentatywne układają się poniżej SNQ przez minimum 10 dni w obrębie jednego obszaru hydrologicznego (który obejmuje grupę zlewni monitorowanych przez PSHM).',
#   'wojewodztwo': 'lubelskie',
#   'obszar': 'zlewnia Bugu od ujścia Uherki do Krzyczewa'},
#  {'opublikowano': '2024-07-17 11:07:57',
#   'stopień': '-1',
#   'data_od': '2024-07-17 11:08:39',
#   'data_do': '9999-12-31 23:59:59',
#   'prawdopodobienstwo': '100',
#   'numer': '202',
#   'biuro': 'Biuro Prognoz Hydrologicznych w Krakowie, Wydział Prognoz i Opracowań Hydrologicznych w Warszawie',
#   'zdarzenie': 'susza hydrologiczna',
#   'przebieg': 'W związku z występującymi niskimi przepływami wody, w kolejnych dniach na Bugu spodziewane jest dalsze utrzymywanie się przepływów wody poniżej SNQ.',
#   'komentarz': 'Zmiana dotyczy korekty edytorskiej',
#   'wojewodztwo': 'mazowieckie',
#   'obszar': 'Bug'},
#  {'opublikowano': '2024-07-31 10:20:23',
#   'stopień': '-1',
#   'data_od': '2024-07-31 10:30:00',
#   'data_do': '9999-12-31 23:59:59',
#   'prawdopodobienstwo': '100',
#   'numer': '130',
#   'biuro': 'Biuro Prognoz Hydrologicznych we Wrocławiu, Wydział Prognoz i Opracowań Hydrologicznych w Poznaniu',
#   'zdarzenie': 'susza hydrologiczna',
#   'przebieg': 'W związku z występującymi niskimi przepływami wody, w kolejnych dniach w zlewni Przyrzecza Warty środkowej od Wełny do Noteci spodziewane jest dalsze utrzymywanie się przepływów wody poniżej SNQ.',
#   'komentarz': 'Ostrzeżenie wydawane jest w sytuacji, gdy aktualne lub prognozowane wartości przepływu na stacjach wodowskazowych uznanych za reprezentatywne układają się poniżej SNQ przez minimum 10 dni w obrębie jednego obszaru hydrologicznego (który obejmuje grupę zlewni monitorowanych przez PSHM).',
#   'wojewodztwo': 'lubuskie',
#   'obszar': 'przyrzecze Warty środkowej od Wełny do Noteci'},
#  {'opublikowano': '2024-08-01 10:55:53',
#   'stopień': '-1',
#   'data_od': '2024-08-01 10:56:48',
#   'data_do': '9999-12-31 23:59:59',
#   'prawdopodobienstwo': '90',
#   'numer': '132',
#   'biuro': 'Biuro Prognoz Hydrologicznych we Wrocławiu, Wydział Prognoz i Opracowań Hydrologicznych w Poznaniu',
#   'zdarzenie': 'susza hydrologiczna',
#   'przebieg': 'W związku z występującymi niskimi przepływami wody, w kolejnych dniach na obszarze zlewni Iny i Płoni spodziewane jest dalsze utrzymywanie się przepływów wody poniżej SNQ.',
#   'komentarz': 'Ostrzeżenie wydawane jest w sytuacji, gdy aktualne lub prognozowane wartości przepływu na stacjach wodowskazowych uznanych za reprezentatywne układają się poniżej SNQ przez minimum 10 dni w obrębie jednego obszaru hydrologicznego (który obejmuje grupę zlewni monitorowanych przez PSHM).',
#   'wojewodztwo': 'zachodniopomorskie',
#   'obszar': 'zlewnia Iny i Płoni'},
#  {'opublikowano': '2024-09-17 21:41:21',
#   'stopień': '3',
#   'data_od': '2024-09-17 21:42:15',
#   'data_do': '2024-09-19 22:00:00',
#   'prawdopodobienstwo': '90',
#   'numer': '205',
#   'biuro': 'Biuro Prognoz Hydrologicznych we Wrocławiu, Wydział Prognoz i Opracowań Hydrologicznych we Wrocławiu',
#   'zdarzenie': 'wezbranie stany alarmowe ',
#   'przebieg': 'Na Odrze środkowej skanalizowanej i swobodnie płynącej do Głogowa prognozowane są wzrosty stanów wody do strefy stanów wysokich i powyżej stanów ostrzegawczych, a następnie alarmowych.',
#   'komentarz': 'Zmiana dotyczy obszaru oraz czasu obowiązywania.',
#   'wojewodztwo': 'dolnośląskie',
#   'obszar': 'Odra od Chałupek do Koźla, Odra od Koźla do ujścia Nysy Kłodzkiej, Odra od ujścia Nysy Kłodzkiej do Trestna, Odra od Trestna do Brzegu Dolnego, Odra od Brzegu Dolnego do ujścia Baryczy, Odra od ujścia Baryczy do ujścia Bobru'},
#  {'opublikowano': '2024-08-13 11:00:06',
#   'stopień': '-1',
#   'data_od': '2024-08-13 11:00:45',
#   'data_do': '9999-12-31 23:59:59',
#   'prawdopodobienstwo': '90',
#   'numer': '143',
#   'biuro': 'Biuro Prognoz Hydrologicznych we Wrocławiu, Wydział Prognoz i Opracowań Hydrologicznych w Poznaniu',
#   'zdarzenie': 'susza hydrologiczna',
#   'przebieg': 'W związku z występującymi niskimi przepływami wody, w kolejnych dniach na obszarze zlewni przyrzecza Odry dolnej od Warty do Gryfina spodziewane jest dalsze utrzymywanie się przepływów wody poniżej SNQ.',
#   'komentarz': 'Ostrzeżenie wydawane jest w sytuacji, gdy aktualne lub prognozowane wartości przepływu na stacjach wodowskazowych uznanych za reprezentatywne układają się poniżej SNQ przez minimum 10 dni w obrębie jednego obszaru hydrologicznego (który obejmuje grupę zlewni monitorowanych przez PSHM).',
#   'wojewodztwo': 'lubuskie',
#   'obszar': 'Przyrzecze Odry dolnej od Warty do Gryfina'},
#  {'opublikowano': '2024-09-02 10:10:51',
#   'stopień': '-1',
#   'data_od': '2024-09-02 10:11:43',
#   'data_do': '9999-12-31 23:59:59',
#   'prawdopodobienstwo': '95',
#   'numer': '406',
#   'biuro': 'Biuro Prognoz Hydrologicznych w Krakowie, Wydział Prognoz i Opracowań Hydrologicznych w Krakowie',
#   'zdarzenie': 'susza hydrologiczna',
#   'przebieg': 'W związku z występującymi niskimi przepływami wody na obszarze zlewni Łęgu i przyrzecza Wisły spodziewane jest dalsze utrzymywanie się przepływów wody poniżej SNQ.',
#   'komentarz': 'Ostrzeżenie wydawane jest w sytuacji, gdy aktualne lub prognozowane wartości przepływu na stacjach wodowskazowych uznanych za reprezentatywne układają się poniżej SNQ przez minimum 10 dni w obrębie jednego obszaru hydrologicznego (który obejmuje grupę zlewni monitorowanych przez PSHM).',
#   'wojewodztwo': 'podkarpackie',
#   'obszar': 'Łęg i przyrzecze Wisły'},
#  {'opublikowano': '2024-09-16 08:46:58',
#   'stopień': '3',
#   'data_od': '2024-09-16 11:00:00',
#   'data_do': '2024-09-20 11:00:00',
#   'prawdopodobienstwo': '95',
#   'numer': '209',
#   'biuro': 'Biuro Prognoz Hydrologicznych we Wrocławiu, Wydział Prognoz i Opracowań Hydrologicznych we Wrocławiu',
#   'zdarzenie': 'wezbranie stany alarmowe ',
#   'przebieg': 'W wyniku znaczących opadów deszczu w zlewni Baryczy utrzymuje się tendencja wzrostowa stanów wody w strefie powyżej stanów alarmowych, lokalnie ostrzegawczych. Na Baryczy stany wody będą rosły do strefy powyżej stanów alarmowych.',
#   'komentarz': 'Brak',
#   'wojewodztwo': 'dolnośląskie',
#   'obszar': 'Barycz od Polskiej Wody do ujścia do Odry, Barycz bez Orli i Polskiego Rowu, Orla, Polski Rów'},
#  {'opublikowano': '2024-09-04 09:27:31',
#   'stopień': '-1',
#   'data_od': '2024-09-04 10:00:00',
#   'data_do': '9999-12-31 23:59:59',
#   'prawdopodobienstwo': '90',
#   'numer': '237',
#   'biuro': 'Biuro Prognoz Hydrologicznych w Krakowie, Wydział Prognoz i Opracowań Hydrologicznych w Warszawie',
#   'zdarzenie': 'susza hydrologiczna',
#   'przebieg': 'W związku z występującymi niskimi przepływami wody, w kolejnych dniach w zlewni Wisły od ujścia Narwi do ujścia Zgłowiączki wraz ze zlewnią Zgłowiączki spodziewane jest dalsze utrzymywanie się przepływów wody poniżej SNQ.',
#   'komentarz': 'Ostrzeżenie wydawane jest w sytuacji, gdy aktualne lub prognozowane wartości przepływu na stacjach wodowskazowych uznanych za reprezentatywne układają się poniżej SNQ przez minimum 10 dni w obrębie jednego obszaru hydrologicznego (który obejmuje grupę zlewni monitorowanych przez PSHM).',
#   'wojewodztwo': 'kujawsko-pomorskie',
#   'obszar': 'Wisła od ujścia Narwi do Zb. Włocławek, Wisła od ujścia Narwi po Zb. Włocławek, Wisła od Zb. Włocławek do ujścia Zgłowiączki, Zgłowiączka'},
#  {'opublikowano': '2024-09-19 12:20:02',
#   'stopień': '3',
#   'data_od': '2024-09-19 12:30:00',
#   'data_do': '2024-09-27 06:00:00',
#   'prawdopodobienstwo': '90',
#   'numer': '172',
#   'biuro': 'Biuro Prognoz Hydrologicznych we Wrocławiu, Wydział Prognoz i Opracowań Hydrologicznych w Poznaniu',
#   'zdarzenie': 'wezbranie stany alarmowe ',
#   'przebieg': 'Stany wody na Odrze granicznej w województwie zachodniopomorskim będą miały tendencję wzrostową w strefie wody wysokiej, na stacjach hydrologicznych Gozdowice i Bielinek początkowo z przekroczeniem stanu ostrzegawczego a następnie alarmowego.',
#   'komentarz': 'W przypadku istotnych zmian w czasie lub przebiegu zjawiska ostrzeżenie może ulec zmianie.',
#   'wojewodztwo': 'zachodniopomorskie',
#   'obszar': 'Odra graniczna w województwie zachodniopomorskim'},
#  {'opublikowano': '2024-09-04 10:34:10',
#   'stopień': '-1',
#   'data_od': '2024-09-04 10:34:43',
#   'data_do': '9999-12-31 23:59:59',
#   'prawdopodobienstwo': '95',
#   'numer': '147',
#   'biuro': 'Biuro Prognoz Hydrologicznych w Gdyni, Wydział Prognoz i Opracowań Hydrologicznych w Gdyni',
#   'zdarzenie': 'susza hydrologiczna',
#   'przebieg': 'W związku z występującymi niskimi przepływami wody, w kolejnych dniach, na obszarze zlewni rzeki Drwęca od Welu do Rypienicy, spodziewane jest dalsze utrzymywanie się przepływów wody poniżej SNQ.',
#   'komentarz': 'Ostrzeżenie wydawane jest w sytuacji, gdy aktualne lub prognozowane wartości przepływu na stacjach wodowskazowych uznanych za reprezentatywne układają się poniżej SNQ przez minimum 10 dni w obrębie jednego obszaru hydrologicznego (który obejmuje grupę zlewni monitorowanych przez PSHM).',
#   'wojewodztwo': 'kujawsko-pomorskie',
#   'obszar': 'Drwęca od Welu do Rypienicy'},
#  {'opublikowano': '2024-09-05 09:49:46',
#   'stopień': '-1',
#   'data_od': '2024-09-05 09:50:34',
#   'data_do': '9999-12-31 23:59:59',
#   'prawdopodobienstwo': '95',
#   'numer': '148',
#   'biuro': 'Biuro Prognoz Hydrologicznych w Gdyni, Wydział Prognoz i Opracowań Hydrologicznych w Gdyni',
#   'zdarzenie': 'susza hydrologiczna',
#   'przebieg': 'W związku z występującymi niskimi przepływami wody, w kolejnych dniach, na obszarze zlewni rzeki Wierzyca od Bożegopola Szlacheckiego do ujścia, spodziewane jest dalsze utrzymywanie się przepływów wody poniżej SNQ.',
#   'komentarz': 'Ostrzeżenie wydawane jest w sytuacji, gdy aktualne lub prognozowane wartości przepływu na stacjach wodowskazowych uznanych za reprezentatywne układają się poniżej SNQ przez minimum 10 dni w obrębie jednego obszaru hydrologicznego (który obejmuje grupę zlewni monitorowanych przez PSHM).',
#   'wojewodztwo': 'pomorskie',
#   'obszar': 'Wierzyca od Bożegopola Szlacheckiego do ujścia'},
#  {'opublikowano': '2024-08-20 10:19:23',
#   'stopień': '-1',
#   'data_od': '2024-08-20 10:20:16',
#   'data_do': '9999-12-31 23:59:59',
#   'prawdopodobienstwo': '90',
#   'numer': '139',
#   'biuro': 'Biuro Prognoz Hydrologicznych w Gdyni, Wydział Prognoz i Opracowań Hydrologicznych w Gdyni',
#   'zdarzenie': 'susza hydrologiczna',
#   'przebieg': 'W związku z występującymi niskimi przepływami wody, w kolejnych dniach, na obszarze zlewni rzeki Elbląg, spodziewane jest dalsze utrzymywanie się przepływów wody poniżej SNQ.',
#   'komentarz': 'Ostrzeżenie wydawane jest w sytuacji, gdy aktualne lub prognozowane wartości przepływu na stacjach wodowskazowych uznanych za reprezentatywne układają się poniżej SNQ przez minimum 10 dni w obrębie jednego obszaru hydrologicznego (który obejmuje grupę zlewni monitorowanych przez PSHM).',
#   'wojewodztwo': 'pomorskie',
#   'obszar': 'Elbląg'},
#  {'opublikowano': '2024-09-18 11:04:50',
#   'stopień': '3',
#   'data_od': '2024-09-18 11:05:24',
#   'data_do': '2024-09-19 22:00:00',
#   'prawdopodobienstwo': '90',
#   'numer': '215',
#   'biuro': 'Biuro Prognoz Hydrologicznych we Wrocławiu, Wydział Prognoz i Opracowań Hydrologicznych we Wrocławiu',
#   'zdarzenie': 'wezbranie stany alarmowe ',
#   'przebieg': 'Na dolnych odcinkach rzeki Bystrzycy i Strzegomki utrzyma się znaczne przekroczenie stanów alarmowych z możliwością występowania wahań, a od drugiej połowy okresu z powolną tendencją spadkową.',
#   'komentarz': 'Brak',
#   'wojewodztwo': 'dolnośląskie',
#   'obszar': 'Bystrzyca od Zb. Mietków do ujścia, Strzegomka od Zb. Dobromierz do ujścia do Bystrzycy'},
#  {'opublikowano': '2024-09-09 07:52:51',
#   'stopień': '-1',
#   'data_od': '2024-09-09 07:53:42',
#   'data_do': '9999-12-31 23:59:59',
#   'prawdopodobienstwo': '95',
#   'numer': '239',
#   'biuro': 'Biuro Prognoz Hydrologicznych w Krakowie, Wydział Prognoz i Opracowań Hydrologicznych w Warszawie',
#   'zdarzenie': 'susza hydrologiczna',
#   'przebieg': 'W związku z występującymi niskimi przepływami wody, w kolejnych dniach na Wiśle i przyrzeczu Wisły od Dęblina do ujścia Narwi, spodziewane jest dalsze utrzymywanie się przepływów wody poniżej SNQ.',
#   'komentarz': 'Ostrzeżenie wydawane jest w sytuacji, gdy aktualne lub prognozowane wartości przepływu na stacjach wodowskazowych uznanych za reprezentatywne układają się poniżej SNQ przez minimum 10 dni w obrębie jednego obszaru hydrologicznego (który obejmuje grupę zlewni monitorowanych przez PSHM).',
#   'wojewodztwo': 'mazowieckie',
#   'obszar': 'Wisła od Dęblina do ujścia Narwi'},
#  {'opublikowano': '2024-09-18 11:08:31',
#   'stopień': '3',
#   'data_od': '2024-09-18 11:09:05',
#   'data_do': '2024-09-20 11:00:00',
#   'prawdopodobienstwo': '90',
#   'numer': '216',
#   'biuro': 'Biuro Prognoz Hydrologicznych we Wrocławiu, Wydział Prognoz i Opracowań Hydrologicznych we Wrocławiu',
#   'zdarzenie': 'wezbranie stany alarmowe ',
#   'przebieg': 'Na dolnym odcinku Bobru utrzyma się znaczne przekroczenie stanów alarmowych z tendencją wzrostową lub stabilizacją stanów wody w pierwszej połowie okresu i stabilizacją lub powolnym opadaniem w drugiej połowie okresu. W ujściowym odcinku mogą występować wahania stanów wody, a wzrosty spowodowane dodatkowo przyborem wody na Odrze.',
#   'komentarz': 'Brak',
#   'wojewodztwo': 'lubuskie',
#   'obszar': 'Bóbr od ujścia Kwisy do ujścia do Odry'},
#  {'opublikowano': '2024-08-19 07:59:40',
#   'stopień': '-1',
#   'data_od': '2024-08-19 08:00:39',
#   'data_do': '9999-12-31 23:59:59',
#   'prawdopodobienstwo': '95',
#   'numer': '229',
#   'biuro': 'Biuro Prognoz Hydrologicznych w Krakowie, Wydział Prognoz i Opracowań Hydrologicznych w Warszawie',
#   'zdarzenie': 'susza hydrologiczna',
#   'przebieg': 'W związku z występującymi niskimi przepływami wody, w kolejnych dniach na obszarze zlewni Węgorapy, spodziewane jest dalsze utrzymywanie się przepływów wody poniżej SNQ.',
#   'komentarz': 'Ostrzeżenie wydawane jest w sytuacji, gdy aktualne lub prognozowane wartości przepływu na stacjach wodowskazowych uznanych za reprezentatywne układają się poniżej SNQ przez minimum 10 dni w obrębie jednego obszaru hydrologicznego (który obejmuje grupę zlewni monitorowanych przez PSHM).',
#   'wojewodztwo': 'warmińsko-mazurskie',
#   'obszar': 'zlewnia Węgorapy'},
#  {'opublikowano': '2024-09-11 12:09:50',
#   'stopień': '-1',
#   'data_od': '2024-09-11 12:10:33',
#   'data_do': '9999-12-31 23:59:59',
#   'prawdopodobienstwo': '95',
#   'numer': '149',
#   'biuro': 'Biuro Prognoz Hydrologicznych w Gdyni, Wydział Prognoz i Opracowań Hydrologicznych w Gdyni',
#   'zdarzenie': 'susza hydrologiczna',
#   'przebieg': 'W związku z występującymi niskimi przepływami wody, w kolejnych dniach na Wiśle od Zbiornika Włocławek do Torunia spodziewane jest dalsze utrzymywanie się przepływów wody poniżej SNQ.',
#   'komentarz': 'Zmiana dotyczy obszaru oraz czasu obowiązywania.',
#   'wojewodztwo': 'kujawsko-pomorskie',
#   'obszar': 'Wisła od Zb. Włocławek do Torunia (rz)'},
#  {'opublikowano': '2024-09-18 11:13:35',
#   'stopień': '3',
#   'data_od': '2024-09-18 11:14:16',
#   'data_do': '2024-09-19 22:00:00',
#   'prawdopodobienstwo': '90',
#   'numer': '217',
#   'biuro': 'Biuro Prognoz Hydrologicznych we Wrocławiu, Wydział Prognoz i Opracowań Hydrologicznych we Wrocławiu',
#   'zdarzenie': 'wezbranie stany alarmowe ',
#   'przebieg': 'Na dolnej Nysie Łużyckiej przewiduje się dalszy wzrost stanu wody przy przekroczonym stanie alarmowym w Gubinie, a następnie spodziewana jest stabilizacja. Na stan wody ujściowego odcinka rzeki wpływ będzie miał przybór wody na Odrze. Spadki stanu wody powinny się zaznaczyć w drugiej połowie okresu, szczególnie na Nysie Łużyckiej powyżej Gubina.',
#   'komentarz': 'Brak',
#   'wojewodztwo': 'lubuskie',
#   'obszar': 'Nysa Łużycka od Zgorzelca do ujścia do Odry'},
#  {'opublikowano': '2024-09-16 12:21:46',
#   'stopień': '3',
#   'data_od': '2024-09-17 11:00:00',
#   'data_do': '2024-09-23 11:00:00',
#   'prawdopodobienstwo': '95',
#   'numer': '210',
#   'biuro': 'Biuro Prognoz Hydrologicznych we Wrocławiu, Wydział Prognoz i Opracowań Hydrologicznych we Wrocławiu',
#   'zdarzenie': 'wezbranie stany alarmowe ',
#   'przebieg': 'Stany wody na Odrze środkowej będą miały tendencję wzrostową w strefie wody wysokiej, początkowo z przekroczeniem stanów ostrzegawczych a następnie alarmowych. ',
#   'komentarz': 'Ostrzeżenie może być aktualizowane zależnie od rozwoju sytuacji hydrologicznej ',
#   'wojewodztwo': 'dolnośląskie',
#   'obszar': 'Odra od ujścia Baryczy do ujścia Bobru, Odra od ujścia Bobru do Słubic'},
#  {'opublikowano': '2024-08-26 10:22:32',
#   'stopień': '-1',
#   'data_od': '2024-08-26 10:23:08',
#   'data_do': '9999-12-31 23:59:59',
#   'prawdopodobienstwo': '90',
#   'numer': '144',
#   'biuro': 'Biuro Prognoz Hydrologicznych w Gdyni, Wydział Prognoz i Opracowań Hydrologicznych w Gdyni',
#   'zdarzenie': 'susza hydrologiczna',
#   'przebieg': 'W związku z występującymi niskimi przepływami wody, w kolejnych dniach, na obszarze zlewni rzeki Drwęca - od Welu do Rypienicy, spodziewane jest dalsze utrzymywanie się przepływów wody poniżej SNQ.',
#   'komentarz': 'Ostrzeżenie wydawane jest w sytuacji, gdy aktualne lub prognozowane wartości przepływu na stacjach wodowskazowych uznanych za reprezentatywne układają się poniżej SNQ przez minimum 10 dni w obrębie jednego obszaru hydrologicznego (który obejmuje grupę zlewni monitorowanych przez PSHM).',
#   'wojewodztwo': 'warmińsko-mazurskie',
#   'obszar': 'Drwęca od Welu do Rypienicy'},
#  {'opublikowano': '2024-08-23 09:51:13',
#   'stopień': '-1',
#   'data_od': '2024-08-23 09:51:59',
#   'data_do': '9999-12-31 23:59:59',
#   'prawdopodobienstwo': '90',
#   'numer': '143',
#   'biuro': 'Biuro Prognoz Hydrologicznych w Gdyni, Wydział Prognoz i Opracowań Hydrologicznych w Gdyni',
#   'zdarzenie': 'susza hydrologiczna',
#   'przebieg': 'W związku z występującymi niskimi przepływami wody, w kolejnych dniach, na obszarze zlewni Pasłęki od Wałszy do ujścia, spodziewane jest dalsze utrzymywanie się przepływów wody poniżej SNQ.',
#   'komentarz': 'Ostrzeżenie wydawane jest w sytuacji, gdy aktualne lub prognozowane wartości przepływu na stacjach wodowskazowych uznanych za reprezentatywne układają się poniżej SNQ przez minimum 10 dni w obrębie jednego obszaru hydrologicznego (który obejmuje grupę zlewni monitorowanych przez PSHM).',
#   'wojewodztwo': 'warmińsko-mazurskie',
#   'obszar': 'Pasłęka od Wałszy do ujścia, Zalew Wiślany - Banówka i Świeża'}]

# %%
api_warning_meteo = WARNINGS(warning_type="meteo")

# Pobieranie ostrzeżeń meteorologicznych
api_warning_meteo.get_warnings()
# Out:
# Status code: 200
# [{'id': 'Sk20240919092917293',
#   'nazwa_zdarzenia': 'Gęsta mgła',
#   'stopien': '1',
#   'prawdopodobienstwo': '80',
#   'obowiazuje_do': '2024-09-20 09:00:00',
#   'obowiazuje_od': '2024-09-19 22:00:00',
#   'opublikowano': '2024-09-19 11:29:00',
#   'tresc': 'Prognozuje się gęste mgły, głównie w kotlinach górskich - widzialność lokalnie ograniczona poniżej 200 m.',
#   'komentarz': 'Brak.',
#   'biuro': 'Centralne Biuro Prognoz Meteorologicznych w Warszawie',
#   'teryt': ['0206', '0207', '0221', '0208', '0210', '0212', '0261']},
#  {'id': 'Sk20240919092918592',
#   'nazwa_zdarzenia': 'Gęsta mgła',
#   'stopien': '1',
#   'prawdopodobienstwo': '80',
#   'obowiazuje_do': '2024-09-20 09:00:00',
#   'obowiazuje_od': '2024-09-19 22:00:00',
#   'opublikowano': '2024-09-19 11:29:00',
#   'tresc': 'Prognozuje się gęste mgły - widzialność lokalnie poniżej 200 m.',
#   'komentarz': 'Brak.',
#   'biuro': 'Centralne Biuro Prognoz Meteorologicznych w Warszawie',
#   'teryt': ['2208', '2215', '2211']}]
