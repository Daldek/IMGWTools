# %%
import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parent.joinpath('code')))

# %%
from imgw_spatial import *

# %% [markdown]
# <h1>Mapy</h1>

# %% [markdown]
# <h3>Hydro</h3>

# %%
hydro_station_map = StationMap(station_id=150160180, data_type='hydro', shapefile_path=r"../data/shp/polska.shp")
print(hydro_station_map.measurement_data)
hydro_station_map.plot_map()
# Out:
# Status code: 200
# [{'kod_stacji': '150160180', 'nazwa_stacji': 'KŁODZKO', 'lon': '16.658611', 'lat': '50.4425', 'stan': '123', 'stan_data': '2024-11-29 08:50:00', 'przelyw': '22', 'przeplyw_data': '2024-11-29 08:50:00'}]

# %% [markdown]
# <h3>Synop</h3>

# %%
hydro_station_map.plot_stations_from_csv(r"../data/hydro_stations_locations.csv")

# %%
synop_station_map = StationMap(station_id=12500, data_type='synop', shapefile_path=r"../data/shp/polska.shp")
print(synop_station_map.measurement_data)
# Out:
# Status code: 200
# Synoptic data have no information on the location of the stations
# {'id_stacji': '12500', 'stacja': 'Jelenia Góra', 'data_pomiaru': '2024-11-29', 'godzina_pomiaru': '9', 'temperatura': '3.7', 'predkosc_wiatru': '3', 'kierunek_wiatru': '320', 'wilgotnosc_wzgledna': '89.2', 'suma_opadu': '7.9', 'cisnienie': '1030.6'}

# %% [markdown]
# <h3>Meteo</h3>

# %%
meteo_station_map = StationMap(station_id=351160425, data_type='meteo', shapefile_path=r"../data/shp/polska.shp")
print(meteo_station_map.measurement_data)
meteo_station_map.plot_map()
# Out:
# Status code: 200
# [{'kod_stacji': '351160425', 'nazwa_stacji': 'WROCŁAW', 'lon': '16.881667', 'lat': '51.113611', 'temperatura_gruntu': '5', 'temperatura_gruntu_data': '2024-11-29 08:50:00', 'wiatr_kierunek': '333', 'wiatr_kierunek_data': '2024-11-29 08:50:00', 'wiatr_srednia_predkosc': '6.2', 'wiatr_srednia_predkosc_data': '2024-11-29 08:50:00', 'wiatr_predkosc_maksymalna': '9.3', 'wiatr_predkosc_maksymalna_data': '2024-11-29 08:50:00', 'wilgotnosc_wzgledna': '91', 'wilgotnosc_wzgledna_data': '2024-11-29 08:50:00', 'wiatr_poryw_10min': None, 'wiatr_poryw_10min_data': None, 'opad_10min': '0', 'opad_10min_data': '2024-11-29 08:50:00'}]
