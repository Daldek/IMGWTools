# %%
import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parent))

# %%
from spatial import *

# %% [markdown]
# <h1>Mapy</h1>

# %%
station_map = StationMap(station_id=150160180, shapefile_path=r"../data/shp/polska.shp")
print(station_map.hydro_data)
station_map.plot_map()
# Out:
# Status code: 200
# [{'kod_stacji': '150160180', 'nazwa_stacji': 'KŁODZKO', 'lon': '16.658611', 'lat': '50.4425', 'stan': '202', 'stan_data': '2024-09-19 18:20:00', 'przelyw': '86', 'przeplyw_data': '2024-09-19 18:20:00'}]
